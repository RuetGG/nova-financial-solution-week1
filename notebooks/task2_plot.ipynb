# %%
import sys
import os

sys.path.append(os.path.abspath("..")) 

import glob
from src.data.loader_cleaner import load_data
from src.visualization.plots import plot_all

files = glob.glob("../data/clean/*_metrics.csv")

for f in files:
    df = load_data(f, parse_dates=['Date'])
    stock_name = f.split("/")[-1].split("_")[0] 
    plot_all(df, stock_name)
